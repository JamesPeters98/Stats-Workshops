# %% [markdown]
# # Example of how to use Jupyter
#
# See also the web pages about:
#
# The notebook interface called Jupyter
# https://jupyter.readthedocs.io/en/latest/index.html
#
# The language used is Python (specifically python 2.7, but python 3 also works fine)
# https://www.python.org/doc/
#
# The libraries providing the Maths and statistics functions: Scipy and Numpy
# https://scipy.org/
#
# Finally the graphing engine matplotlib
# http://matplotlib.org/

# %% [markdown]
# ## Cell types
# Cell types can be either code (the default), results (generated by running code cells) or "Markdown" which is documentation for output, like this cell. You can set the cell type from the drop down menu above.
#
# See http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html for details of what you can do in a Markdown cell. Including headers, *highlighting*,
#
#     print("and example code")
#
# Double click on this cell to see how it is formatted and note the "Markdown" cell type in the menu bar.

# %% [markdown]
# # Instructions for completing this workbook
#
# The workbook is desgined for you to attempt at your own pace. The blank cells require you to complete the tasks set in the cell above them. Other cells are information and examples.
#
# To "run" a cell either use shift-return or presee the "Run" button above, the cell below a code cell will also fill with the output "In[x]:" are code cells and "Out[x]:" are the results.

# %%
"""Copy this text into the next cell and set the cell type to Markdown, 
note triple quotes for multiline Python text strings, remove for the markdown cell"""
# Out:
# 'Copy this text into the next cell and set the cell type to Markdown, \nnote triple quotes for multiline Python text strings, remove for the markdown cell'

# %%
"""
Copy this text into the next cell and set the cell type to Markdown, see how different elements work

# Main title

## Sub title

### sub sub title

Text in paragraphs (random psuedo latin gibberish):

Lorem ipsum dolor sit amet, consectetur adipiscing elit. Proin eleifend nec dui vel fringilla. 
In dapibus commodo enim non aliquam. Donec nec libero sed magna fringilla consequat in nec ligula. 
Aliquam erat volutpat. Proin in consectetur diam. Duis sagittis quam et diam congue sagittis. 
Vestibulum dolor felis, semper id ante a, aliquet aliquam elit. Sed consequat tellus in lectus viverra venenatis. 
Praesent aliquet feugiat rhoncus. Etiam interdum eget nibh quis posuere. Fusce eleifend, nulla sed porttitor tincidunt, 
urna sapien molestie orci, eget faucibus leo nunc nec mi. Donec non ex tincidunt, vulputate sem pharetra, vulputate dolor.

Aliquam eu risus gravida, porttitor urna sit amet, dignissim felis. Mauris ipsum purus, elementum ut nunc 
consequat, sollicitudin porttitor risus. In eu pharetra magna. In pharetra ultrices velit, nec faucibus 
justo pellentesque id. Quisque suscipit nec justo vel tempor. Aenean lectus nulla, molestie ut massa id, 
semper bibendum tellus. Maecenas vel fermentum sapien. Cras fringilla efficitur sem, ac blandit dolor 
dictum sed. Praesent augue orci, porta et lectus egestas, aliquet dapibus quam. Nulla in diam ut 
lectus sagittis tincidunt cursus ac nulla. Vivamus ultrices nunc eget arcu venenatis accumsan. Duis 
accumsan ultricies quam, sit amet hendrerit nisl cursus eleifend.

$E=mc^2$ 

equations can also be written in a format called "latex", surround the equation with \$eqn\$ = $eqn$ for inline 
and $$\$\$eqn\$\$=eqn$$ for equations on their own lines.
"""
# Out:
# '\nCopy this text into the next cell and set the cell type to Markdown, see how different elements work\n\n# Main title\n\n## Sub title\n\n### sub sub title\n\nText in paragraphs (random psuedo latin gibberish):\n\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Proin eleifend nec dui vel fringilla. \nIn dapibus commodo enim non aliquam. Donec nec libero sed magna fringilla consequat in nec ligula. \nAliquam erat volutpat. Proin in consectetur diam. Duis sagittis quam et diam congue sagittis. \nVestibulum dolor felis, semper id ante a, aliquet aliquam elit. Sed consequat tellus in lectus viverra venenatis. \nPraesent aliquet feugiat rhoncus. Etiam interdum eget nibh quis posuere. Fusce eleifend, nulla sed porttitor tincidunt, \nurna sapien molestie orci, eget faucibus leo nunc nec mi. Donec non ex tincidunt, vulputate sem pharetra, vulputate dolor.\n\nAliquam eu risus gravida, porttitor urna sit amet, dignissim felis. Mauris ipsum purus, elementum ut nunc \nconsequat, sollic
# ...

# %% [markdown]
# ## Python
# The language is very rich so this is not even a cursory introduction, but an example of some code

# %%
# Everything after a # is a comment for the reader only
var="one" # set a variable called var to the string "one"
v2 = 'two' # set another variable, v2, to "two", variable must start with a letter but can contain numbers
# note "a" and 'a' are both strings, the quotes just have to match
print(var,v2) # note print automatically adds a space between elements if given a list and adds a new line
# Out:
# one two

# %% [markdown]
# ### Set and print variables
#
# Set the variable myText to "my first text variable" and print the content of the variable
#
# Set the variable myNumber to 392.6 and print it

# %% [markdown]
# ## Variable types

# %%
i = 9 # integer
j = 10. # float (as indicated by the decimal point)
l = [11.1,12] # list of float, int
m = ("size","fish",7) # tuple of string, string, int (tuples can not be added to, lists can)
n = [i,j,l,m] # list constructed from existing elements, including both other lists and tuples
o = {'one':1,'two':2} # dictionary relating pairs of elements, first is the key, the second the value

# %% [markdown]
# ### Show how each of the variables will be printed and the "type" of the variable

# %%
print('i',i,type(i)) # type(x) gives the type of x, as a string if printed
print('j',j,type(j))
print('l',l,type(l))
print('m',m,type(m))
print('n',n,type(n))
print('o',o,type(o))
# Out:
# i 9 <class 'int'>
# j 10.0 <class 'float'>
# l [11.1, 12] <class 'list'>
# m ('size', 'fish', 7) <class 'tuple'>
# n [9, 10.0, [11.1, 12], ('size', 'fish', 7)] <class 'list'>
# o {'one': 1, 'two': 2} <class 'dict'>

# %%
# Put the numbers 1 into the variable a1 and 10 into the variable a2, then print a1+a2, a1*a2, a1-a2, a1/a2, a1//a2 and a1%a2 
# what do the last two do and when might you use them?
# https://docs.python.org/3.5/library/stdtypes.html#numeric-types-int-float-complex has documentation for maths operators

# %% [markdown]
# ### Access elements of lists or tuples

# %%
print('l[0] l[1]',l[0],l[1])
print('m[0] m[1] m[2]',m[0],m[1],m[2])
print('o["one"] o["two"]',o["one"],o["two"]) # note if you start a string with ' you can use " in it (and vice versa)
# Out:
# l[0] l[1] 11.1 12
# m[0] m[1] m[2] size fish 7
# o["one"] o["two"] 1 2

# %%
# Fill a list (abc) with "a is for apple", "b is for bannana", "c is for carrot"
# Then print the tenth letter of each phrase (note python counts from zero)

# %% [markdown]
# ## Maths is supported (not supprisingly)

# %%
print('1+2 =',1+2)
print('119.9765/35478. =',119.9765/35478.)
# Out:
# 1+2 = 3
# 119.9765/35478. = 0.0033817154292801175

# %% [markdown]
# ### Examples for you to try
#
# Calculate $x = 7*3 + 2/7 - 16$
#
# then calcuate $y = 125.765 * 0.1023$
#
# and print $x/y$
#
# (Note rules about precedence : https://docs.python.org/3/reference/expressions.html#operator-precedence or always use brackets)

# %% [markdown]
# The equation $$F = \frac{G m_1 m_2}{r^2}$$
# is the force between two objects of masses $m_1$ and $m_2$ due to gravity.
#
# $G$ is the gravitational constant $6.67\times 10^{-11}$ N m$^2$/kg$^2$.
#
#
# For the Earth $m_1 = 5.97\times 10^{24}$ kg and the moon $m_2 = 7.35\times 10^{22}$ kg, when they are $r = 4.02 \times 10^8$ m apart what is the force between then in Newtons?

# %% [markdown]
# ## Conditional statements
#
#     if test:
#         do this if test is True
#     elif test2:
#         do this if test is False and test2 is True #can have zero, one or many elif if there are many choices
#     else:
#         do this if test is False and test2 is False
#
# Conditional statements change what the programme does based on the values in variables

# %%
i = 3
if(i>10):  # if thing in brackets is true do first part
    print(i,'is bigger than 10') # python uses spaces at the start of the line to define blocks of code
    print('Still on true path')
else: # part to do if false
    print(i,'is less than or equal to 10')
    print('Continuing false path')
# end a block by lining the first charater of the string up with the statement before the block
print("do always (after conditional)")
# Out:
# 3 is less than or equal to 10
# Continuing false path
# do always (after conditional)

# %% [markdown]
# ### Example for you to try
#
# In the cell above try changing $i$ on the first line to be 13, 10 or -77
#
# Set fruit = 'apple'
#
# then print the words "fruit is an apple" or "fruit is a bannana" if those statement are true
#
# Test this by changing the code to set fruit = "bannana" to see the change in output
#
# To compare the content of a variable to a string use ==
#
#     var1 == "hello"
#
# is *True* if var1 is "hello" ("hello ", "Hello" and others would all be false)

# %% [markdown]
# ## Loops
#
# Where code does the same block of code repeatedly, usualling changing the a number each time
#
# Like if the block is indented

# %%
# simple for loop over a list
for i in [1,2,4,8,16]:
    print('In this iteratation of the loop i=',i)
print('Loop ends here') 
print() # print blank line

# block ends when next line is "outdented" from loop
# so the last twp prints (above) are only run once 

print("Loop over range(10), means 0,1,2,...,9")
for j in range(10):
    print('In this iteratation of the loop j=',j)
# Out:
# In this iteratation of the loop i= 1
# In this iteratation of the loop i= 2
# In this iteratation of the loop i= 4
# In this iteratation of the loop i= 8
# In this iteratation of the loop i= 16
# Loop ends here
#
# Loop over range(10), means 0,1,2,...,9
# In this iteratation of the loop j= 0
# In this iteratation of the loop j= 1
# In this iteratation of the loop j= 2
# In this iteratation of the loop j= 3
# In this iteratation of the loop j= 4
# In this iteratation of the loop j= 5
# In this iteratation of the loop j= 6
# In this iteratation of the loop j= 7
# In this iteratation of the loop j= 8
# In this iteratation of the loop j= 9

# %% [markdown]
# ### Example for you to try
#
# Write a loop over the elements 1,3,9,27,81, where $e$ is the element
#
# Print the value of $e$ and predicte the next element (i.e. print $e$ and $e\times 3$).

# %% [markdown]
# ### Official python tutorials
# The official python site has tutorials on aspects of python, see section 4 for if, loops etc.
# https://docs.python.org/3.5/tutorial/index.html

# %% [markdown]
# ## How to get help
#
#     ?float (or float?)
#
# shows the "help" for the function "float". Try that in the cell below.

# %% [markdown]
# ### Example for you to try
#
# Get the help for the divmod function and use it to print the divisor and remainder of 121 divided by 13.
# So that if $x$ is the divisor and $y$ is the remainder $121 = x\times 13 + y$, where $x$ and $y$ are integers.

# %% [markdown]
# ## Define your own functions
#
# A function is any block of code that can be run, it may take arguments and return values.
#
# Like other blocks it ends when the next line is "outdented"

# %%
# Example function called func
def func(x,m,c):
    """Text in triple quotes is the help text for the function! This function just returns x*m + c"""
    return x*m + c

# call your new function
print("func(1,2,3)=",func(1,2,3))
print("\nHelp defined for func()\n")
# ?func
# Out:
# func(1,2,3)= 5
#
# Help defined for func()

# %% [markdown]
# ## Numpy and Scipy
# This adds a lot of high level routines. Numpy covers storing and manipulating arrays of numbers, Scipy adds routines such as numerical integration, minimum finding and many other things.
#
# See the documentation for everything they do.
#
# https://docs.scipy.org/doc/

# %%
import numpy as np # now np.x means use the numpy version of x
x = np.linspace(0,20,5) # linspace(a,b,n) is make n equally spaced numbers between a and b
print("x=",x)
# numpy can also process whole arrays at once
print("sqrt(x)=",np.sqrt(x))
# Out:
# x= [ 0.  5. 10. 15. 20.]
# sqrt(x)= [0.         2.23606798 3.16227766 3.87298335 4.47213595]

# %%
from scipy.integrate import quad # import a single routine from a subpackage of scipy
# ?quad # list all of the options for quad

# %%
# integrate func we defined above (func = m*x + c) from 1 to 10, with m=7 and c=2
result, err = quad(func,a=1,b=10,args=(7,2)) # named arguments can be set by order or by name, here two values are returned
# This is a numerical integration so has a small uncertainty:
print("intergal of func(x,7,2) from x = 1 to 10 is {} +- {}".format(result,err))
# Out:
# intergal of func(x,7,2) from x = 1 to 10 is 364.5 +- 4.0467629247586956e-12

# %% [markdown]
# which should be $\int_1^{10} (7x + 2) dx = \left[ \frac{7}{2}x^2+2x \right]_1^{10} = [700/2 + 20] - [7/2 + 2] = 370 - 5.5 = 364.5$
# Double click on this cell to see how to add maths to the output, using the latex language

# %% [markdown]
# ### One for you to try
#
# Integrate $sin(x)$ from 0 to $\pi/2$. Adjust the cell below to get the correct answer, you can check it yourself with a pencil and paper by doing the integral.
#
# Call "quad" with the function np.sin, a = 0, b = np.pi/2 and you do not need args (sin(x) only needs x)

# %%
from scipy.integrate import quad

# %% [markdown]
# ## matplotlib
# Adds graphing to pyton, inside juptyer it can display the plots straigh into the output cells.
#
# https://matplotlib.org

# %%
# First "magic" command to juypter itself instead of python, %? for full list
# This sets up jupyter to display plots from matplotlib
# with an inline display in the cell, without make a new window.
# %matplotlib inline
# then make the python functions to access matplotlib available
import matplotlib.pyplot as plt
x = [1.1,5.3,9.9]
y = [16.3,12.8,18.11]
# draw the arrays x and y defined above
plt.plot(x,y) # plot is the most basic plotting routine, will do auto axies
plt.xlabel('x')
plt.ylabel('y')
plt.show() # always put a plt.show() when you want the plot drawn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
# new plot for x verse np.log10(x)+4
x = np.linspace(0.2,2,100) # note reusing x, so take care when running cells out of order
y = np.log10(x)
f = plt.figure(figsize=(8,6)) # set a 8cm x 6cm window to draw plots in
plt.plot(x,np.log10(x),label="log10(x)") # new option to give a name to the curve
plt.plot(x,np.log(x),label="log(x)") # Another curve (automatically gets a new colour)
plt.plot(x,np.sqrt(x),label="sqrt(x)") # add a third curve, with an explicit colour and dash style
plt.xlabel('x')
plt.ylabel('y')
# can plot data with error bars too, look at the ?plt.errorbar for all of the options
plt.errorbar(x=[0.5,1.0,1.5],y=[-0.5,-0.1,-0.01],yerr=[0.1,0.07,0.15],fmt="o",label="random points")
plt.legend() # draw the labels to define the lines
plt.show() # always put a plt.show() when you want the plot drawn

# %% [markdown]
# Many more things you can do, such as log axies, grid lines, several plots in the same output, set axies ranges etc. See documentaiton for details.

# %% [markdown]
# ## Subplots

# %%
# First "magic" command to juypter itself instead of python, %? for full list
# This sets up jupyter to display plots from matplotlib
# with an inline display in the cell, without make a new window.
# %matplotlib inline
# then make the python functions to access matplotlib available
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
import numpy as np
x = np.array([10,19,32])
y = x**2 + 7
fig = plt.figure(figsize=(8, 6)) # set the default figure size to 8,6 
# now make a 2x2 array of plots and plot into the top left one (i.e. subplot 1)
p = plt.subplot(2,2,1)
p.plot(x,y) # some data to plot as x,y
p.set_title('Top Left')
p.set_xlabel('x')
p.set_ylabel('y')
# plot into the top right (subplot 2)
p = plt.subplot(2,2,2)
p.plot(x,np.sqrt(y)) 
p.set_title('Top Right')
p.set_xlabel('x')
p.set_ylabel('$\sqrt{y}$') # note use of maths in axis label using $ math $
# plot into the bottom left (subplot 3)
p = plt.subplot(2,2,3)
p.plot(x,np.log(y)) 
p.set_title('Bottom Left')
p.set_xlabel('x')
p.set_ylabel('$\ln{(y)}$')
# plot into the bottom right (subplot 4)
p = plt.subplot(2,2,4)
p.plot(np.log10(x),np.log10(y)) 
p.set_title('Bottom Right')
p.set_xlabel('$\log{(x)}$')
p.set_ylabel('$\log{(y)}$')
# now make space for the captions and axis labels
plt.tight_layout()
# always put a show command where a plot should be finished
plt.show()

# %%
help()
